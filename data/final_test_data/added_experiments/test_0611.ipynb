# %%
import pandas as pd
import os

# %%
import numpy as np
def modify_float(num):
    try:
        return str(round(float(num),1))
    except:
        return num
def majority_vote(row):
    # Counting the frequency of each unique value in the row
    counts = row.value_counts()
    if counts.max() == 1:  # This means there is a tie or no majority
        return counts.keys()[0]# Handle no majority case as needed
    return counts.idxmax()  # Return the value with the highest count
def compute_results(df):
    correctness = 0
    sc_correctness = 0
    mad_correctness = 0
    rerailer_correctness = 0
    for row_index in range(len(df)):
        row = df.iloc[row_index]
        correct_ans = row['Correct_Answer'].lower()
        output_answer = row['Cot_random_answer'].lower()
        sc_answer = row['Smv_Answer'].lower()
        # judge_answer = row['Output_Answer'].lower()
        mad_answer = row['MAD_Answer'].lower()
        rerailer_ans = row['Corrected COT Answer'].lower()
        if correct_ans == output_answer[0]:
            correctness += 1
        else:
            correctness += 0
        if correct_ans == sc_answer[0]:
            sc_correctness += 1
        else:
            sc_correctness += 0
        if correct_ans == mad_answer[0]:
            mad_correctness += 1
        else:
            mad_correctness += 0
        if correct_ans == rerailer_ans[0]:
            rerailer_correctness += 1
        else:
            rerailer_correctness += 0
    
    result_dict={
        'CoT':round(correctness/len(df),3),
        'SC':round(sc_correctness/len(df),3),
        'MAD':round(mad_correctness/len(df),3),
        'Rerailer':round(rerailer_correctness/len(df),3)
    }
    return result_dict

# %%
df_all_results = pd.read_csv('rerailer_result_MULTI_claude2.csv')
df_all_results
# Out:
#      CaseID           Category  \
# 0         0   Challenging Math
# 1         1   Challenging Math
# 2         2   Challenging Math
# 3         3   Challenging Math
# 4         4   Challenging Math
# ..      ...                ...
# 260     260  disambiguation_qa
# 261     261  disambiguation_qa
# 262     262  disambiguation_qa
# 263     263  disambiguation_qa
# 264     264  disambiguation_qa
#
#                                               Question Correct Answer  \
# 0    James decides to run 1793815 sprints 1793815 t...    322886700.0
# 1    Every day, Wendi feeds each of her chickens th...     -6887448.0
# 2    Toulouse has twice as many sheep as Charleston...     82085198.0
# 3    Eliza's rate per hour for the first 40 hours s...     74363508.0
# 4    A new program had 531811 downloads in the firs...      3244047.1
# ..                                                 ...            ...
# 260  In the following sentences, explain the antece...              b
# 261  In the following sentences, explain the antece...              c
# 262  In the following sentences, explain the antece...              c
# 263  In the following sentences, explain the antece...              a
# 264  In the following sentences, explain the antece...              c
#
#     Raw COT Answer Corrected COT Answer                       Hallu Seq  \
# 0            193.0  107628.9 kilometers              ['NO', 'NO', 'NO']
# 1             -6.0              29 cups                         ['YES']
# 2       82085198.0           82085198.0        ['NO', 'NO', 'NO', 'NO']
# 3              1.0              $743.36        ['NO', 'NO', 'NO', 'NO']
# 4              3.0                  3.0        ['NO', 'NO', 'NO', 'NO']
# ..             ...                  ...                             ...
# 260              b                    b  ['NO', 'NO', 'NO', 'NO', 'NO']
# 261              c                    c              ['NO', 'NO', 'NO']
# 262              b                    b              ['NO', 'NO', 'NO']
# 263              c                    c        ['NO', 'NO', 'NO', 'NO']
# 264              b                    b        ['NO', 'NO', 'NO', 'NO']
#
#                                                raw_cot  \
# 0    Step 1: Understand the given information.\n- J...
# 1    Step 1: Understand the given information.\r\n-...
# 2    Step 1: Let's define the variables.\r\n       ...
# 3    Step 1: Determine Eliza's regular hourly rate....
# 4    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 260  Step 1: The sentence mentions 'the practitione...
# 261  Step 1: The pronoun 'he' in the given sentence...
# 262  Step 1: The pronoun 'her' in the given sentenc...
# 263  Step 1: The sentence says 'After meeting with ...
# 264  Step 1: The sentence provided is 'The nurse wa...
#
#                                          corrected_cot
# 0    Step 3: Calculate the total distance covered i...
# 1    Step 1: Total feed needed per day for 20 chick...
# 2    Step 1: Let's define the variables.\r\n       ...
# 3    Step 3: Calculate Eliza's earnings for the ove...
# 4    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 260  Step 3: To confirm the antecedent of 'they', l...
# 261  Step 1: The pronoun 'he' in the given sentence...
# 262  Step 1: The pronoun 'her' in the given sentenc...
# 263  Step 1: The sentence says 'After meeting with ...
# 264  Step 2: To further analyze the ambiguity, we n...
#
# [265 rows x 9 columns]

# %%
df_all_results['Category'].value_counts()
# Out:
# Category
# Challenging Math     101
# disambiguation_qa     86
# Math                  78
# Name: count, dtype: int64

# %%
df_original= pd.read_csv('result_claude.csv')
df_original_neg = df_original[~df_original['Consistency']]
df_original_pos = df_original[df_original['Consistency']]
df_original_neg
# Out:
#                        Model           Name           Category  \
# 2    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 3    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 5    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 6    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 7    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# ..                       ...            ...                ...
# 583  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 585  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 586  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 591  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 592  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
#
#                                               Question Correct_Answer  \
# 2    James decides to run 1793815 sprints 1793815 t...    322886700.0
# 3    Every day, Wendi feeds each of her chickens th...     -6887448.0
# 5    Toulouse has twice as many sheep as Charleston...     82085198.0
# 6    Eliza's rate per hour for the first 40 hours s...     74363508.0
# 7    A new program had 531811 downloads in the firs...      3244047.1
# ..                                                 ...            ...
# 583  In the following sentences, explain the antece...              B
# 585  In the following sentences, explain the antece...              C
# 586  In the following sentences, explain the antece...              C
# 591  In the following sentences, explain the antece...              A
# 592  In the following sentences, explain the antece...              C
#
#     Output_Answer  Consistency  \
# 2           193.0        False
# 3            -6.0        False
# 5      82085198.0        False
# 6             1.0        False
# 7             3.0        False
# ..            ...          ...
# 583             B        False
# 585             C        False
# 586             B        False
# 591             C        False
# 592             B        False
#
#                                           Selected_Cot  \
# 2    Step 1: Understand the given information.\n- J...
# 3    Step 1: Understand the given information.\r\n-...
# 5    Step 1: Let's define the variables.\r\n       ...
# 6    Step 1: Determine Eliza's regular hourly rate....
# 7    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 583  Step 1: The sentence mentions 'the practitione...
# 585  Step 1: The pronoun 'he' in the given sentence...
# 586  Step 1: The pronoun 'her' in the given sentenc...
# 591  Step 1: The sentence says 'After meeting with ...
# 592  Step 1: The sentence provided is 'The nurse wa...
#
#                                                   cot1  \
# 2    Step 1: The problem states that James runs 179...
# 3    Step 1: Determine the total amount of feed giv...
# 5    Step 1: We are given that Toulouse has twice a...
# 6    Step 1: Determine Eliza's regular hourly rate....
# 7    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 583  Step 1: The sentence is 'The practitioner made...
# 585  Step 1: The sentence 'Alex did not know Taylor...
# 586  Step 1: The pronoun 'her' in the given sentenc...
# 591  Step 1: The sentence says 'After meeting with ...
# 592  Step 1: The sentence is 'The nurse was running...
#
#                                                   cot2  \
# 2    Step 1: Understand the given information.\n- J...
# 3    Step 1: Understand the given information.\r\n-...
# 5    Step 1: Let's define the variables.\r\n       ...
# 6    Step 1: Identify the given information:\r\n   ...
# 7    \r\n        Step 1: Determine the number of do...
# ..                                                 ...
# 583  Step 1: The sentence mentions 'the practitione...
# 585  Step 1: The pronoun 'he' in the given sentence...
# 586  Step 1: The sentence states 'The student set u...
# 591  Step 1: The given sentence is 'After meeting w...
# 592  Step 1: The sentence provided is 'The nurse wa...
#
#                                                   cot3     answer1  \
# 2    Step 1: Identify the given information.\n- Jam...       193.0
# 3    Step 1: Determine the total amount of feed giv...        -6.0
# 5    Step 1: We are given the following information...  82085198.0
# 6    Step 1: Determine Eliza's regular hourly rate....   1859087.0
# 7    Step 1: Determine the number of downloads in t...         3.0
# ..                                                 ...         ...
# 583  Step 1: The sentence is 'The practitioner made...           B
# 585  Step 1: Identify the pronouns in the given sen...           B
# 586  Step 1: The sentence is 'The student set up a ...           B
# 591  Step 1: The pronoun 'her' in the sentence 'Aft...           C
# 592  Step 1: The sentence is 'The nurse was running...           A
#
#         answer2 answer3
# 2         193.0   192.0
# 3          -6.0   error
# 5    82085198.0    82.0
# 6         763.6     1.0
# 7     3243047.0     3.0
# ..          ...     ...
# 583           B       C
# 585           C       C
# 586           C       C
# 591           C       A
# 592           B       A
#
# [265 rows x 14 columns]

# %%
df_interception = pd.merge(df_original_neg, df_all_results, on=['Category', 'Question'], how='inner',copy=False)
df_interception.drop_duplicates(subset='Question',inplace=True)
df_interception
# Out:
#                        Model           Name           Category  \
# 0    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 1    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 2    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 3    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 4    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# ..                       ...            ...                ...
# 260  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 261  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 262  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 263  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 264  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
#
#                                               Question Correct_Answer  \
# 0    James decides to run 1793815 sprints 1793815 t...    322886700.0
# 1    Every day, Wendi feeds each of her chickens th...     -6887448.0
# 2    Toulouse has twice as many sheep as Charleston...     82085198.0
# 3    Eliza's rate per hour for the first 40 hours s...     74363508.0
# 4    A new program had 531811 downloads in the firs...      3244047.1
# ..                                                 ...            ...
# 260  In the following sentences, explain the antece...              B
# 261  In the following sentences, explain the antece...              C
# 262  In the following sentences, explain the antece...              C
# 263  In the following sentences, explain the antece...              A
# 264  In the following sentences, explain the antece...              C
#
#     Output_Answer  Consistency  \
# 0           193.0        False
# 1            -6.0        False
# 2      82085198.0        False
# 3             1.0        False
# 4             3.0        False
# ..            ...          ...
# 260             B        False
# 261             C        False
# 262             B        False
# 263             C        False
# 264             B        False
#
#                                           Selected_Cot  \
# 0    Step 1: Understand the given information.\n- J...
# 1    Step 1: Understand the given information.\r\n-...
# 2    Step 1: Let's define the variables.\r\n       ...
# 3    Step 1: Determine Eliza's regular hourly rate....
# 4    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 260  Step 1: The sentence mentions 'the practitione...
# 261  Step 1: The pronoun 'he' in the given sentence...
# 262  Step 1: The pronoun 'her' in the given sentenc...
# 263  Step 1: The sentence says 'After meeting with ...
# 264  Step 1: The sentence provided is 'The nurse wa...
#
#                                                   cot1  \
# 0    Step 1: The problem states that James runs 179...
# 1    Step 1: Determine the total amount of feed giv...
# 2    Step 1: We are given that Toulouse has twice a...
# 3    Step 1: Determine Eliza's regular hourly rate....
# 4    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 260  Step 1: The sentence is 'The practitioner made...
# 261  Step 1: The sentence 'Alex did not know Taylor...
# 262  Step 1: The pronoun 'her' in the given sentenc...
# 263  Step 1: The sentence says 'After meeting with ...
# 264  Step 1: The sentence is 'The nurse was running...
#
#                                                   cot2  ...     answer1  \
# 0    Step 1: Understand the given information.\n- J...  ...       193.0
# 1    Step 1: Understand the given information.\r\n-...  ...        -6.0
# 2    Step 1: Let's define the variables.\r\n       ...  ...  82085198.0
# 3    Step 1: Identify the given information:\r\n   ...  ...   1859087.0
# 4    \r\n        Step 1: Determine the number of do...  ...         3.0
# ..                                                 ...  ...         ...
# 260  Step 1: The sentence mentions 'the practitione...  ...           B
# 261  Step 1: The pronoun 'he' in the given sentence...  ...           B
# 262  Step 1: The sentence states 'The student set u...  ...           B
# 263  Step 1: The given sentence is 'After meeting w...  ...           C
# 264  Step 1: The sentence provided is 'The nurse wa...  ...           A
#
#         answer2 answer3 CaseID  Correct Answer Raw COT Answer  \
# 0         193.0   192.0      0     322886700.0          193.0
# 1          -6.0   error      1      -6887448.0           -6.0
# 2    82085198.0    82.0      2      82085198.0     82085198.0
# 3         763.6     1.0      3      74363508.0            1.0
# 4     3243047.0     3.0      4       3244047.1            3.0
# ..          ...     ...    ...             ...            ...
# 260           B       C    260               b              b
# 261           C       C    261               c              c
# 262           C       C    262               c              b
# 263           C       A    263               a              c
# 264           B       A    264               c              b
#
#     Corrected COT Answer                       Hallu Seq  \
# 0    107628.9 kilometers              ['NO', 'NO', 'NO']
# 1                29 cups                         ['YES']
# 2             82085198.0        ['NO', 'NO', 'NO', 'NO']
# 3                $743.36        ['NO', 'NO', 'NO', 'NO']
# 4                    3.0        ['NO', 'NO', 'NO', 'NO']
# ..                   ...                             ...
# 260                    b  ['NO', 'NO', 'NO', 'NO', 'NO']
# 261                    c              ['NO', 'NO', 'NO']
# 262                    b              ['NO', 'NO', 'NO']
# 263                    c        ['NO', 'NO', 'NO', 'NO']
# 264                    b        ['NO', 'NO', 'NO', 'NO']
#
#                                                raw_cot  \
# 0    Step 1: Understand the given information.\n- J...
# 1    Step 1: Understand the given information.\r\n-...
# 2    Step 1: Let's define the variables.\r\n       ...
# 3    Step 1: Determine Eliza's regular hourly rate....
# 4    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 260  Step 1: The sentence mentions 'the practitione...
# 261  Step 1: The pronoun 'he' in the given sentence...
# 262  Step 1: The pronoun 'her' in the given sentenc...
# 263  Step 1: The sentence says 'After meeting with ...
# 264  Step 1: The sentence provided is 'The nurse wa...
#
#                                          corrected_cot
# 0    Step 3: Calculate the total distance covered i...
# 1    Step 1: Total feed needed per day for 20 chick...
# 2    Step 1: Let's define the variables.\r\n       ...
# 3    Step 3: Calculate Eliza's earnings for the ove...
# 4    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 260  Step 3: To confirm the antecedent of 'they', l...
# 261  Step 1: The pronoun 'he' in the given sentence...
# 262  Step 1: The pronoun 'her' in the given sentenc...
# 263  Step 1: The sentence says 'After meeting with ...
# 264  Step 2: To further analyze the ambiguity, we n...
#
# [264 rows x 21 columns]

# %%
df_original_pos['Corrected COT Answer'] = df_original_pos['Output_Answer']
df_original_pos['Corrected COT Answer']
df_original_pos
# Out:
# C:\Users\77388\AppData\Local\Temp\ipykernel_46464\1774958068.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_original_pos['Corrected COT Answer'] = df_original_pos['Output_Answer']
#                        Model           Name           Category  \
# 0    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 1    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 4    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 8    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 13   claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# ..                       ...            ...                ...
# 587  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 588  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 589  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 590  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 593  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
#
#                                               Question Correct_Answer  \
# 0    Janet’s ducks lay 16 eggs per day. She eats th...     -9867630.0
# 1    A robe takes 2287720 bolts of blue fiber and h...      3431580.0
# 4    Kylar went to the store to buy glasses for his...     21459061.0
# 8    Toula went to the bakery and bought various ty...     17414074.0
# 13   Billy sells DVDs. He has 8 customers on Tuesda...      1379135.0
# ..                                                 ...            ...
# 587  In the following sentences, explain the antece...              B
# 588  In the following sentences, explain the antece...              B
# 589  In the following sentences, explain the antece...              C
# 590  In the following sentences, explain the antece...              A
# 593  In the following sentences, explain the antece...              B
#
#     Output_Answer  Consistency Selected_Cot  \
# 0             0.0         True          NaN
# 1       3431580.0         True          NaN
# 4            21.0         True          NaN
# 8            17.0         True          NaN
# 13          475.0         True          NaN
# ..            ...          ...          ...
# 587             B         True          NaN
# 588             B         True          NaN
# 589             C         True          NaN
# 590             C         True          NaN
# 593             C         True          NaN
#
#                                                   cot1  \
# 0    Step 1: Determine the total number of eggs lai...
# 1    Step 1: The robe takes 2287720 bolts of blue f...
# 4    Step 1: Understand the problem statement.\r\n ...
# 8    Step 1: Identify the different types of pastri...
# 13   Step 1: Identify the given information.\r\n   ...
# ..                                                 ...
# 587  Step 1: In the given sentence, the pronoun 'hi...
# 588  Step 1: Identify the pronouns in the sentence....
# 589  Step 1: Identify the pronoun in the sentence. ...
# 590  Step 1: The sentence is 'The educator was meet...
# 593  Step 1: In the given sentence, the pronoun 'th...
#
#                                                   cot2  \
# 0    Step 1: Determine the total number of eggs lai...
# 1    Step 1: The question states that the robe take...
# 4    Step 1: Determine the cost of each glass.\r\n ...
# 8    Step 1: Identify the different types of pastri...
# 13   Step 1: Identify the given information.\r\n- B...
# ..                                                 ...
# 587  Step 1: The sentence is 'After meeting with th...
# 588  Step 1: Identify the pronouns in the given sen...
# 589  Step 1: Identify the pronoun in the sentence. ...
# 590  Step 1: The sentence states 'their grading pol...
# 593  Step 1: The sentence is 'The designer collabor...
#
#                                                   cot3    answer1    answer2  \
# 0    Step 1: Determine the number of eggs laid by J...        0.0        0.0
# 1    Step 1: The question states that a robe takes ...  3431580.0  3431580.0
# 4    Step 1: Determine the total number of glasses ...       21.0       21.0
# 8    Step 1: Identify the given information.\r\nTou...       17.0       17.0
# 13   \r\n        Step 1: Identify the given informa...      475.0      475.0
# ..                                                 ...        ...        ...
# 587  Step 1: Identify the pronoun in the sentence. ...          B          B
# 588  Step 1: The pronoun 'him' in the given sentenc...          B          B
# 589  Step 1: The given sentence is 'The developer m...          C          C
# 590  Step 1: The sentence mentions 'the educator' a...          C          C
# 593  Step 1: The pronoun 'them' in the sentence 'Th...          C          C
#
#        answer3 Corrected COT Answer
# 0          0.0                  0.0
# 1    3431580.0            3431580.0
# 4         21.0                 21.0
# 8         17.0                 17.0
# 13       475.0                475.0
# ..         ...                  ...
# 587          B                    B
# 588          B                    B
# 589          C                    C
# 590          C                    C
# 593          C                    C
#
# [329 rows x 15 columns]

# %%
df = pd.concat([df_interception,df_original_pos],ignore_index=True)
df = df.apply(modify_float,axis=0)
df
# Out:
#                        Model           Name           Category  \
# 0    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 1    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 2    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 3    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# 4    claude-3-haiku-20240307     GSM8K_hard   Challenging Math
# ..                       ...            ...                ...
# 588  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 589  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 590  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 591  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
# 592  claude-3-haiku-20240307  BigBench_hard  disambiguation_qa
#
#                                               Question Correct_Answer  \
# 0    James decides to run 1793815 sprints 1793815 t...    322886700.0
# 1    Every day, Wendi feeds each of her chickens th...     -6887448.0
# 2    Toulouse has twice as many sheep as Charleston...     82085198.0
# 3    Eliza's rate per hour for the first 40 hours s...     74363508.0
# 4    A new program had 531811 downloads in the firs...      3244047.1
# ..                                                 ...            ...
# 588  In the following sentences, explain the antece...              B
# 589  In the following sentences, explain the antece...              B
# 590  In the following sentences, explain the antece...              C
# 591  In the following sentences, explain the antece...              A
# 592  In the following sentences, explain the antece...              B
#
#     Output_Answer  Consistency  \
# 0           193.0        False
# 1            -6.0        False
# 2      82085198.0        False
# 3             1.0        False
# 4             3.0        False
# ..            ...          ...
# 588             B         True
# 589             B         True
# 590             C         True
# 591             C         True
# 592             C         True
#
#                                           Selected_Cot  \
# 0    Step 1: Understand the given information.\n- J...
# 1    Step 1: Understand the given information.\r\n-...
# 2    Step 1: Let's define the variables.\r\n       ...
# 3    Step 1: Determine Eliza's regular hourly rate....
# 4    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 588                                                NaN
# 589                                                NaN
# 590                                                NaN
# 591                                                NaN
# 592                                                NaN
#
#                                                   cot1  \
# 0    Step 1: The problem states that James runs 179...
# 1    Step 1: Determine the total amount of feed giv...
# 2    Step 1: We are given that Toulouse has twice a...
# 3    Step 1: Determine Eliza's regular hourly rate....
# 4    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 588  Step 1: In the given sentence, the pronoun 'hi...
# 589  Step 1: Identify the pronouns in the sentence....
# 590  Step 1: Identify the pronoun in the sentence. ...
# 591  Step 1: The sentence is 'The educator was meet...
# 592  Step 1: In the given sentence, the pronoun 'th...
#
#                                                   cot2  ...     answer1  \
# 0    Step 1: Understand the given information.\n- J...  ...       193.0
# 1    Step 1: Understand the given information.\r\n-...  ...        -6.0
# 2    Step 1: Let's define the variables.\r\n       ...  ...  82085198.0
# 3    Step 1: Identify the given information:\r\n   ...  ...   1859087.0
# 4    \r\n        Step 1: Determine the number of do...  ...         3.0
# ..                                                 ...  ...         ...
# 588  Step 1: The sentence is 'After meeting with th...  ...           B
# 589  Step 1: Identify the pronouns in the given sen...  ...           B
# 590  Step 1: Identify the pronoun in the sentence. ...  ...           C
# 591  Step 1: The sentence states 'their grading pol...  ...           C
# 592  Step 1: The sentence is 'The designer collabor...  ...           C
#
#         answer2 answer3 CaseID  Correct Answer Raw COT Answer  \
# 0         193.0   192.0    0.0     322886700.0          193.0
# 1          -6.0   error    1.0      -6887448.0           -6.0
# 2    82085198.0    82.0    2.0      82085198.0     82085198.0
# 3         763.6     1.0    3.0      74363508.0            1.0
# 4     3243047.0     3.0    4.0       3244047.1            3.0
# ..          ...     ...    ...             ...            ...
# 588           B       B    NaN             NaN            NaN
# 589           B       B    NaN             NaN            NaN
# 590           C       C    NaN             NaN            NaN
# 591           C       C    NaN             NaN            NaN
# 592           C       C    NaN             NaN            NaN
#
#     Corrected COT Answer                 Hallu Seq  \
# 0    107628.9 kilometers        ['NO', 'NO', 'NO']
# 1                29 cups                   ['YES']
# 2             82085198.0  ['NO', 'NO', 'NO', 'NO']
# 3                $743.36  ['NO', 'NO', 'NO', 'NO']
# 4                    3.0  ['NO', 'NO', 'NO', 'NO']
# ..                   ...                       ...
# 588                    B                       NaN
# 589                    B                       NaN
# 590                    C                       NaN
# 591                    C                       NaN
# 592                    C                       NaN
#
#                                                raw_cot  \
# 0    Step 1: Understand the given information.\n- J...
# 1    Step 1: Understand the given information.\r\n-...
# 2    Step 1: Let's define the variables.\r\n       ...
# 3    Step 1: Determine Eliza's regular hourly rate....
# 4    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 588                                                NaN
# 589                                                NaN
# 590                                                NaN
# 591                                                NaN
# 592                                                NaN
#
#                                          corrected_cot
# 0    Step 3: Calculate the total distance covered i...
# 1    Step 1: Total feed needed per day for 20 chick...
# 2    Step 1: Let's define the variables.\r\n       ...
# 3    Step 3: Calculate Eliza's earnings for the ove...
# 4    Step 1: Determine the number of downloads in t...
# ..                                                 ...
# 588                                                NaN
# 589                                                NaN
# 590                                                NaN
# 591                                                NaN
# 592                                                NaN
#
# [593 rows x 21 columns]

# %%
# df.to_csv('result_c3.csv',index=False)
# df = pd.read_csv('paper_report_df.csv')

# %%
correctness = 0
sc_correctness = 0
judge_correctness = 0
rerailer_correctness = 0
for row_index in range(len(df)):
    row = df.iloc[row_index]
    correct_ans = row['Correct_Answer'].lower()
    output_answer = row['Cot_random_answer'].lower()
    sc_answer = row['Smv_Answer'].lower()
    judge_answer = row['Output_Answer'].lower()
    rerailer_ans = row['Corrected COT Answer'].lower()
    if correct_ans == output_answer[0]:
        correctness += 1
    else:
        correctness += 0
    if correct_ans == sc_answer[0]:
        sc_correctness += 1
    else:
        sc_correctness += 0
    if correct_ans == judge_answer[0]:
        judge_correctness += 1
    else:
        judge_correctness += 0
    if correct_ans == rerailer_ans[0]:
        rerailer_correctness += 1
    else:
        rerailer_correctness += 0


correctness/len(df),sc_correctness/len(df),judge_correctness/len(df),rerailer_correctness/len(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File W:\anaconda3\envs\llm_hall_project\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File W:\anaconda3\envs\llm_hall_project\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File W:\anaconda3\envs\llm_hall_project\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cot_random_answer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[199], line 8
#       6 row = df.iloc[row_index]
#       7 correct_ans = row['Correct_Answer'].lower()
# ----> 8 output_answer = row['Cot_random_answer'].lower()
#       9 sc_answer = row['Smv_Answer'].lower()
#      10 judge_answer = row['Output_Answer'].lower()
#
# File W:\anaconda3\envs\llm_hall_project\lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File W:\anaconda3\envs\llm_hall_project\lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File W:\anaconda3\envs\llm_hall_project\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Cot_random_answer'

# %%
df_new = pd.read_csv('result_claude.csv')
df_new.rename(columns={'Selected_Cot':'Cot'},inplace=True)
df_new
# Out:
#                      Category  \
# 0     professional_accounting
# 1     professional_accounting
# 2     professional_accounting
# 3     professional_accounting
# 4     professional_accounting
# ...                       ...
# 2476        disambiguation_qa
# 2477        disambiguation_qa
# 2478        disambiguation_qa
# 2479        disambiguation_qa
# 2480        disambiguation_qa
#
#                                                Question Correct_Answer  \
# 0     Which of the following items is not subject to...              D
# 1     Pine Co. purchased land for $450000 as a facto...              C
# 2     Spark Co. buys cordless phones for $125 each a...              D
# 3     The standard deviations of Stocks A and B are ...              A
# 4     A shoe retailer allows customers to return sho...              B
# ...                                                 ...            ...
# 2476  In the following sentences, explain the antece...              B
# 2477  In the following sentences, explain the antece...              B
# 2478  In the following sentences, explain the antece...              C
# 2479  In the following sentences, explain the antece...              A
# 2480  In the following sentences, explain the antece...              B
#
#                                           Output_Answer  Consistency  \
# 0                                                     B        False
# 1                                                     A        False
# 2                                                     D        False
# 3     None of the options match the calculated value...        False
# 4                                                     B        False
# ...                                                 ...          ...
# 2476                                                  B         True
# 2477                                                  B         True
# 2478                                                  C         True
# 2479                                                  C         True
# 2480                                                  C         True
#
#                                                     Cot  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 1: Calculate the profit per unit by subtr...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
# 2479                                                NaN
# 2480                                                NaN
#
#                                              Cot_Answer  \
# 0                                                     D
# 1                                                     A
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                           C) $195,000
# ...                                                 ...
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
# 2479                                                NaN
# 2480                                                NaN
#
#                                              Smv_Answer  \
# 0                                                     B
# 1                                                     D
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                           C) $195,000
# ...                                                 ...
# 2476                                                  B
# 2477                                                  B
# 2478                                                  C
# 2479                                                  C
# 2480                                                  C
#
#                                              Cot_random  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     step 1: Understand that the cost of the comple...
# 2     step 1: Calculate the desired profit margin, w...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
# 2479                                                NaN
# 2480                                                NaN
#
#                                       Cot_random_answer  ...  \
# 0                                                     B  ...
# 1                                                     D  ...
# 2     The calculation process was flawed, leading to...  ...
# 3     None of the options match the calculated value...  ...
# 4                                           C) $195,000  ...
# ...                                                 ...  ...
# 2476                                                  B  ...
# 2477                                                  B  ...
# 2478                                                  C  ...
# 2479                                                  C  ...
# 2480                                                  C  ...
#
#                                                 raw_cot  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 1: Calculate the profit per unit by subtr...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
# 2479                                                NaN
# 2480                                                NaN
#
#                                           corrected_cot  \
# 0     Step 1: To answer which item is not subject to...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 4: To summarize the thought process:\n\nS...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
# 2479                                                NaN
# 2480                                                NaN
#
#                         Model           Name  \
# 0                         NaN            NaN
# 1                         NaN            NaN
# 2                         NaN            NaN
# 3                         NaN            NaN
# 4                         NaN            NaN
# ...                       ...            ...
# 2476  claude-3-haiku-20240307  BigBench_hard
# 2477  claude-3-haiku-20240307  BigBench_hard
# 2478  claude-3-haiku-20240307  BigBench_hard
# 2479  claude-3-haiku-20240307  BigBench_hard
# 2480  claude-3-haiku-20240307  BigBench_hard
#
#                                                    cot1  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2476  Step 1: In the given sentence, the pronoun 'hi...
# 2477  Step 1: Identify the pronouns in the sentence....
# 2478  Step 1: Identify the pronoun in the sentence. ...
# 2479  Step 1: The sentence is 'The educator was meet...
# 2480  Step 1: In the given sentence, the pronoun 'th...
#
#                                                    cot2  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2476  Step 1: The sentence is 'After meeting with th...
# 2477  Step 1: Identify the pronouns in the given sen...
# 2478  Step 1: Identify the pronoun in the sentence. ...
# 2479  Step 1: The sentence states 'their grading pol...
# 2480  Step 1: The sentence is 'The designer collabor...
#
#                                                    cot3 answer1 answer2  \
# 0                                                   NaN     NaN     NaN
# 1                                                   NaN     NaN     NaN
# 2                                                   NaN     NaN     NaN
# 3                                                   NaN     NaN     NaN
# 4                                                   NaN     NaN     NaN
# ...                                                 ...     ...     ...
# 2476  Step 1: Identify the pronoun in the sentence. ...       B       B
# 2477  Step 1: The pronoun 'him' in the given sentenc...       B       B
# 2478  Step 1: The given sentence is 'The developer m...       C       C
# 2479  Step 1: The sentence mentions 'the educator' a...       C       C
# 2480  Step 1: The pronoun 'them' in the sentence 'Th...       C       C
#
#      answer3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 2476       B
# 2477       B
# 2478       C
# 2479       C
# 2480       C
#
# [2481 rows x 25 columns]

# %%
df_new.Correct_Answer=df_new.Correct_Answer.apply(modify_float)
df_new.Output_Answer=df_new.Output_Answer.apply(modify_float)
df_new.answer1=df_new.answer1.apply(modify_float)
df_new.answer2=df_new.answer2.apply(modify_float)
df_new.answer3=df_new.answer3.apply(modify_float)

# %%
df_new['Cot_random_answer'] = df_new['answer1']
df_new['Smv_Answer'] = df_new[['answer1','answer2','answer3']].apply(majority_vote, axis=1)
df_new.apply(modify_float,axis=0)
# Out:
#                      Category  \
# 0     professional_accounting
# 1     professional_accounting
# 2     professional_accounting
# 3     professional_accounting
# 4     professional_accounting
# ...                       ...
# 2476        disambiguation_qa
# 2477        disambiguation_qa
# 2478        disambiguation_qa
# 2479        disambiguation_qa
# 2480        disambiguation_qa
#
#                                                Question Correct_Answer  \
# 0     Which of the following items is not subject to...              D
# 1     Pine Co. purchased land for $450000 as a facto...              C
# 2     Spark Co. buys cordless phones for $125 each a...              D
# 3     The standard deviations of Stocks A and B are ...              A
# 4     A shoe retailer allows customers to return sho...              B
# ...                                                 ...            ...
# 2476  In the following sentences, explain the antece...              B
# 2477  In the following sentences, explain the antece...              B
# 2478  In the following sentences, explain the antece...              C
# 2479  In the following sentences, explain the antece...              A
# 2480  In the following sentences, explain the antece...              B
#
#                                           Output_Answer  Consistency  \
# 0                                                     B        False
# 1                                                     A        False
# 2                                                     D        False
# 3     None of the options match the calculated value...        False
# 4                                                     B        False
# ...                                                 ...          ...
# 2476                                                  B         True
# 2477                                                  B         True
# 2478                                                  C         True
# 2479                                                  C         True
# 2480                                                  C         True
#
#                                                     Cot  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 1: Calculate the profit per unit by subtr...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
# 2479                                                NaN
# 2480                                                NaN
#
#                                              Cot_Answer Smv_Answer  \
# 0                                                     D        nan
# 1                                                     A        nan
# 2     The calculation process was flawed, leading to...        nan
# 3     None of the options match the calculated value...        nan
# 4                                           C) $195,000        nan
# ...                                                 ...        ...
# 2476                                                NaN          B
# 2477                                                NaN          B
# 2478                                                NaN          C
# 2479                                                NaN          C
# 2480                                                NaN          C
#
#                                              Cot_random Cot_random_answer  \
# 0     Step 1: Understand what intraperiod tax alloca...               nan
# 1     step 1: Understand that the cost of the comple...               nan
# 2     step 1: Calculate the desired profit margin, w...               nan
# 3     Step 1: Understand that the standard deviation...               nan
# 4     Step 1: Understand the problem. The company ne...               nan
# ...                                                 ...               ...
# 2476                                                NaN                 B
# 2477                                                NaN                 B
# 2478                                                NaN                 C
# 2479                                                NaN                 C
# 2480                                                NaN                 C
#
#       ...                                            raw_cot  \
# 0     ...  Step 1: Understand what intraperiod tax alloca...
# 1     ...  Step 1: Understand that the cost to be capital...
# 2     ...  Step 1: Calculate the profit per unit by subtr...
# 3     ...  Step 1: Understand that the standard deviation...
# 4     ...  Step 1: Understand the problem. The company ne...
# ...   ...                                                ...
# 2476  ...                                                NaN
# 2477  ...                                                NaN
# 2478  ...                                                NaN
# 2479  ...                                                NaN
# 2480  ...                                                NaN
#
#                                           corrected_cot  \
# 0     Step 1: To answer which item is not subject to...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 4: To summarize the thought process:\n\nS...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
# 2479                                                NaN
# 2480                                                NaN
#
#                         Model           Name  \
# 0                         NaN            NaN
# 1                         NaN            NaN
# 2                         NaN            NaN
# 3                         NaN            NaN
# 4                         NaN            NaN
# ...                       ...            ...
# 2476  claude-3-haiku-20240307  BigBench_hard
# 2477  claude-3-haiku-20240307  BigBench_hard
# 2478  claude-3-haiku-20240307  BigBench_hard
# 2479  claude-3-haiku-20240307  BigBench_hard
# 2480  claude-3-haiku-20240307  BigBench_hard
#
#                                                    cot1  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2476  Step 1: In the given sentence, the pronoun 'hi...
# 2477  Step 1: Identify the pronouns in the sentence....
# 2478  Step 1: Identify the pronoun in the sentence. ...
# 2479  Step 1: The sentence is 'The educator was meet...
# 2480  Step 1: In the given sentence, the pronoun 'th...
#
#                                                    cot2  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2476  Step 1: The sentence is 'After meeting with th...
# 2477  Step 1: Identify the pronouns in the given sen...
# 2478  Step 1: Identify the pronoun in the sentence. ...
# 2479  Step 1: The sentence states 'their grading pol...
# 2480  Step 1: The sentence is 'The designer collabor...
#
#                                                    cot3 answer1 answer2  \
# 0                                                   NaN     nan     nan
# 1                                                   NaN     nan     nan
# 2                                                   NaN     nan     nan
# 3                                                   NaN     nan     nan
# 4                                                   NaN     nan     nan
# ...                                                 ...     ...     ...
# 2476  Step 1: Identify the pronoun in the sentence. ...       B       B
# 2477  Step 1: The pronoun 'him' in the given sentenc...       B       B
# 2478  Step 1: The given sentence is 'The developer m...       C       C
# 2479  Step 1: The sentence mentions 'the educator' a...       C       C
# 2480  Step 1: The pronoun 'them' in the sentence 'Th...       C       C
#
#      answer3
# 0        nan
# 1        nan
# 2        nan
# 3        nan
# 4        nan
# ...      ...
# 2476       B
# 2477       B
# 2478       C
# 2479       C
# 2480       C
#
# [2481 rows x 25 columns]

# %%
# df_new = pd.concat([df_new,df],ignore_index=True)
correctness = 0
sc_correctness = 0
judge_correctness = 0
rerailer_correctness = 0
for row_index in range(len(df_new)):
    row = df_new.iloc[row_index]
    correct_ans = row['Correct_Answer'].lower()
    output_answer = row['Cot_random_answer'].lower()
    sc_answer = row['Smv_Answer'].lower()
    judge_answer = row['Output_Answer'].lower()

    if correct_ans == output_answer[0]:
        correctness += 1
    else:
        correctness += 0
    if correct_ans == sc_answer[0]:
        sc_correctness += 1
    else:
        sc_correctness += 0
    if correct_ans == judge_answer[0]:
        judge_correctness += 1
    else:
        judge_correctness += 0



correctness/len(df_new),sc_correctness/len(df_new),judge_correctness/len(df_new)
# Out:
# (0.07174526400644901, 0.07496977025392987, 0.6952841596130592)

# %%
df_new.to_csv('cleaned_result_claude.csv',index=False)

# %%
feature_li = ['Category','Question','Consistency','raw_cot','corrected_cot','Correct_Answer','Cot_random_answer', 'Smv_Answer','Output_Answer','Corrected COT Answer']

# %%
df_3 = pd.read_csv('final_result_gpt3.5.csv')
df_4 = pd.read_csv('final_result_gpt4.csv')
df_claude = pd.read_csv('final_result_claude3.csv')

# %%
df_3[feature_li].to_csv('../../../result/gpt3.5_results.csv',index=False)
df_4[feature_li].to_csv('../../../result/gpt4_results.csv',index=False)
df_claude[feature_li].to_csv('../../../result/claude_results.csv',index=False)

# %%
results_li = []
result = compute_results(df_3)
result['Model'] = 'gpt-3.5-turbo'
result['Category'] = 'all'
results_li.append(pd.DataFrame(result, index=[0]))
for cate in set(df_3.Category.tolist()):
    df_temp = df_3[df_3['Category']==cate]
    result = compute_results(df_temp)
    result['Model'] = 'gpt-3.5-turbo'
    result['Category'] = cate
    results_li.append(pd.DataFrame(result, index=[0]))
df_result_3 = pd.concat(results_li,ignore_index=True)[['Category','Model','CoT','SC','Derailer','Rerailer']]
df_result_3
# Out:
#                     Category          Model    CoT     SC  Derailer  Rerailer
# 0                        all  gpt-3.5-turbo  0.675  0.692     0.709     0.730
# 1     elementary_mathematics  gpt-3.5-turbo  0.970  0.970     0.980     0.980
# 2           college_medicine  gpt-3.5-turbo  0.819  0.809     0.819     0.819
# 3          disambiguation_qa  gpt-3.5-turbo  0.455  0.455     0.455     0.445
# 4              jurisprudence  gpt-3.5-turbo  0.919  0.939     0.939     0.939
# 5           abstract_algebra  gpt-3.5-turbo  0.758  0.789     0.821     0.789
# 6                       Math  gpt-3.5-turbo  0.366  0.380     0.393     0.485
# 7        college_mathematics  gpt-3.5-turbo  0.753  0.852     0.901     0.889
# 8          international_law  gpt-3.5-turbo  0.908  0.908     0.898     0.908
# 9            college_biology  gpt-3.5-turbo  0.918  0.939     0.929     0.949
# 10         college_chemistry  gpt-3.5-turbo  0.699  0.723     0.735     0.735
# 11    high_school_statistics  gpt-3.5-turbo  0.784  0.835     0.876     0.876
# 12           college_physics  gpt-3.5-turbo  0.823  0.854     0.854     0.844
# 13                philosophy  gpt-3.5-turbo  0.802  0.812     0.844     0.865
# 14    electrical_engineering  gpt-3.5-turbo  0.677  0.698     0.750     0.781
# 15              formal_logic  gpt-3.5-turbo  0.808  0.782     0.782     0.782
# 16           business_ethics  gpt-3.5-turbo  0.740  0.760     0.771     0.771
# 17  college_computer_science  gpt-3.5-turbo  0.833  0.854     0.875     0.865
# 18          professional_law  gpt-3.5-turbo  0.687  0.697     0.687     0.687
# 19   professional_accounting  gpt-3.5-turbo  0.714  0.736     0.835     0.846
# 20        date_understanding  gpt-3.5-turbo  0.859  0.889     0.889     0.869
# 21          Challenging Math  gpt-3.5-turbo  0.378  0.385     0.406     0.497

# %%
results_li = []
result = compute_results(df_4)
result['Model'] = 'gpt-4'
result['Category'] = 'all'
results_li.append(pd.DataFrame(result, index=[0]))
for cate in set(df_4.Category.tolist()):
    df_temp = df_4[df_4['Category']==cate]
    result = compute_results(df_temp)
    result['Model'] = 'gpt-4'
    result['Category'] = cate
    results_li.append(pd.DataFrame(result, index=[0]))
df_result_4 = pd.concat(results_li,ignore_index=True)[['Category','Model','CoT','SC','Derailer','Rerailer']]
df_result_4
# Out:
#                     Category  Model    CoT     SC  Derailer  Rerailer
# 0                        all  gpt-4  0.694  0.711     0.727     0.748
# 1     elementary_mathematics  gpt-4  0.970  0.970     0.980     0.980
# 2           college_medicine  gpt-4  0.819  0.809     0.819     0.830
# 3          disambiguation_qa  gpt-4  0.460  0.460     0.460     0.525
# 4              jurisprudence  gpt-4  0.919  0.939     0.939     0.939
# 5           abstract_algebra  gpt-4  0.758  0.789     0.821     0.821
# 6                       Math  gpt-4  0.480  0.493     0.507     0.527
# 7        college_mathematics  gpt-4  0.753  0.852     0.901     0.914
# 8          international_law  gpt-4  0.908  0.908     0.898     0.898
# 9            college_biology  gpt-4  0.918  0.939     0.929     0.959
# 10         college_chemistry  gpt-4  0.699  0.723     0.735     0.759
# 11    high_school_statistics  gpt-4  0.784  0.835     0.876     0.876
# 12           college_physics  gpt-4  0.823  0.854     0.844     0.854
# 13                philosophy  gpt-4  0.802  0.812     0.844     0.854
# 14    electrical_engineering  gpt-4  0.677  0.698     0.750     0.771
# 15              formal_logic  gpt-4  0.808  0.782     0.782     0.769
# 16           business_ethics  gpt-4  0.740  0.760     0.771     0.760
# 17  college_computer_science  gpt-4  0.833  0.854     0.875     0.875
# 18          professional_law  gpt-4  0.687  0.697     0.687     0.697
# 19   professional_accounting  gpt-4  0.714  0.736     0.835     0.868
# 20        date_understanding  gpt-4  0.859  0.889     0.889     0.889
# 21          Challenging Math  gpt-4  0.421  0.428     0.448     0.517

# %%
results_li = []
result = compute_results(df_claude)
result['Model'] = 'gpt-4'
result['Category'] = 'all'
results_li.append(pd.DataFrame(result, index=[0]))
for cate in set(df_4.Category.tolist()):
    df_temp = df_4[df_4['Category']==cate]
    result = compute_results(df_temp)
    result['Model'] = 'gpt-4'
    result['Category'] = cate
    results_li.append(pd.DataFrame(result, index=[0]))
df_result_4 = pd.concat(results_li,ignore_index=True)[['Category','Model','CoT','SC','Derailer','Rerailer']]
df_result_4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 2
#       1 results_li = []
# ----> 2 result = compute_results(df_claude)
#       3 result['Model'] = 'gpt-4'
#       4 result['Category'] = 'all'
#
# NameError: name 'df_claude' is not defined

# %%
df_mad = pd.read_csv('gpt_3.5_MAD_result_MULTI.csv')
df_mad
# Out:
#      CaseID           Category  \
# 0         0   Challenging Math
# 1         1   Challenging Math
# 2         2   Challenging Math
# 3         3   Challenging Math
# 4         4   Challenging Math
# ..      ...                ...
# 272     220  disambiguation_qa
# 273     221  disambiguation_qa
# 274     222  disambiguation_qa
# 275     223  disambiguation_qa
# 276     224  disambiguation_qa
#
#                                               Question Correct Answer  \
# 0    Janet’s ducks lay 16 eggs per day. She eats th...       -9867630
# 1    James decides to run 1793815 sprints 1793815 t...      322886700
# 2    Every day, Wendi feeds each of her chickens th...       -6887448
# 3    Kylar went to the store to buy glasses for his...       21459061
# 4    Toulouse has twice as many sheep as Charleston...       82085198
# ..                                                 ...            ...
# 272  In the following sentences, explain the antece...              c
# 273  In the following sentences, explain the antece...              c
# 274  In the following sentences, explain the antece...              a
# 275  In the following sentences, explain the antece...              c
# 276  In the following sentences, explain the antece...              b
#
#                                               ori_cot1  \
# 0    Step 1: Calculate the total number of eggs Jan...
# 1    \r\n        Step 1: Calculate the total meters...
# 2                                                error
# 3    Step 1: Calculate the total number of glasses ...
# 4    \r\nStep 1: Let's denote the number of sheep i...
# ..                                                 ...
# 272  Step 1: Identify the pronoun in the sentence. ...
# 273  Step 1: Identify the pronoun in the sentence. ...
# 274  Step 1: The pronoun 'their' in the sentence re...
# 275  Step 1: Identify the pronoun in the sentence. ...
# 276                                              error
#
#                                               ori_cot2  ori_ans1   ori_ans2  \
# 0    \r\n        Step 1: Calculate the total number...  19735200    1973528
# 1    \r\n        Step 1: Calculate the total meters...        14  107628900
# 2    \r\n        Step 1: Calculate the total amount...     error         35
# 3    Step 1: Calculate the total number of glasses ...         2   16119180
# 4    \r\nStep 1: Let's denote the number of sheep i...  82085198   37885476
# ..                                                 ...       ...        ...
# 272  Step 1: Identify the pronoun in the sentence. ...         b          b
# 273  Step 1: Identify the pronoun in the sentence. ...         a          a
# 274  Step 1: Identify the pronoun in the sentence. ...         b          a
# 275  Step 1: Identify the pronoun in the sentence. ...         b          a
# 276  Step 1: The pronoun 'them' in the sentence 'Th...     error          b
#
#                                                   cot1  \
# 0    The solution provided by the other agents cont...
# 1    The solution provided by the other agents cont...
# 2    To determine how many cups of feed Wendi needs...
# 3    The initial solution provided by the other age...
# 4    The solution provided by the other agents is c...
# ..                                                 ...
# 272  Step 1: Identify the pronoun in the sentence. ...
# 273  The pronoun 'he' in the sentence 'Alex did not...
# 274  The pronoun 'their' in the sentence refers bac...
# 275  The full solution provided by the other agents...
# 276  In the sentence 'The designer collaborated wit...
#
#                                                   cot2  \
# 0    The solution provided by the other agents cont...
# 1    The solution provided by the other agents is m...
# 2    The solution provided by the other agents is m...
# 3    The solution provided by the other agents is m...
# 4    The solution provided by the other agents is c...
# ..                                                 ...
# 272  Step 1: Identify the pronoun in the sentence. ...
# 273  The full solution provided by the other agents...
# 274  The pronoun 'their' in the sentence 'The educa...
# 275  Step 1: Identify the pronoun in the sentence. ...
# 276  The pronoun 'them' in the sentence 'The design...
#
#                            ans1  \
# 0                            20
# 1        193276073935000 meters
# 2    Error in problem statement
# 3                    21,459,061
# 4                      82085198
# ..                          ...
# 272                           C
# 273                           C
# 274                           B
# 275                           A
# 276                           C
#
#                                                   ans2   MAD_answer
# 0                                                 $20            20
# 1                               193062269353500 meters  1.93276E+14
# 2    The problem statement contains a likely typo o...        error
# 3                                         $21,459,061      21459061
# 4                                             82085200     82085198
# ..                                                 ...          ...
# 272                                                  C            C
# 273                                                  C            C
# 274                                                  A            B
# 275                                                  A            A
# 276                                                  B            C
#
# [277 rows x 13 columns]

# %%
df_c3 = pd.read_csv('../../../result/gpt3.5_results.csv')
df_c3
# Out:
#                      Category  \
# 0     professional_accounting
# 1     professional_accounting
# 2     professional_accounting
# 3     professional_accounting
# 4     professional_accounting
# ...                       ...
# 2469        disambiguation_qa
# 2470        disambiguation_qa
# 2471        disambiguation_qa
# 2472        disambiguation_qa
# 2473        disambiguation_qa
#
#                                                Question  Consistency  \
# 0     Which of the following items is not subject to...        False
# 1     Pine Co. purchased land for $450000 as a facto...        False
# 2     Spark Co. buys cordless phones for $125 each a...        False
# 3     The standard deviations of Stocks A and B are ...        False
# 4     A shoe retailer allows customers to return sho...        False
# ...                                                 ...          ...
# 2469  In the following sentences, explain the antece...         True
# 2470  In the following sentences, explain the antece...         True
# 2471  In the following sentences, explain the antece...         True
# 2472  In the following sentences, explain the antece...         True
# 2473  In the following sentences, explain the antece...         True
#
#                                                 raw_cot  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 1: Calculate the profit per unit by subtr...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2469                                                NaN
# 2470                                                NaN
# 2471                                                NaN
# 2472                                                NaN
# 2473                                                NaN
#
#                                           corrected_cot Correct_Answer  \
# 0     Step 1: Understand what intraperiod tax alloca...              D
# 1     Step 1: Understand that the cost to be capital...              C
# 2     Step 1: Calculate the profit per unit by subtr...              D
# 3     Step 1: Understand that the standard deviation...              A
# 4     Step 1: Understand the problem. The company ne...              B
# ...                                                 ...            ...
# 2469                                                NaN              C
# 2470                                                NaN              B
# 2471                                                NaN              B
# 2472                                                NaN              C
# 2473                                                NaN              A
#
#                                       Cot_random_answer  \
# 0                                                     B
# 1                                                     D
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2469                                                  A
# 2470                                                  B
# 2471                                                  B
# 2472                                                  C
# 2473                                                  A
#
#                                              Smv_Answer  \
# 0                                                     B
# 1                                                     D
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2469                                                  A
# 2470                                                  B
# 2471                                                  B
# 2472                                                  C
# 2473                                                  A
#
#                                           Output_Answer Corrected COT Answer
# 0                                                     B                    b
# 1                                                     A                    a
# 2                                                     D                    d
# 3     None of the options match the calculated value...                    a
# 4                                                     B                    b
# ...                                                 ...                  ...
# 2469                                                  A                    A
# 2470                                                  B                    B
# 2471                                                  B                    B
# 2472                                                  C                    C
# 2473                                                  A                    A
#
# [2474 rows x 10 columns]

# %%
def get_answer(string):
    splits = string.split('final_answer')
    if len(splits)>1:
        return splits[-1]
    else:return string

# %%
# df_mad = df_mad.apply(modify_float,axis=0)
# df_mad['MAD_answer']= df_mad['MAD_answer'].apply(get_answer)
# df_mad

# %%
# df_mad.to_csv('MAD_result_MULTI_claude.csv',index=False)

# %%
df_mad = df_mad.apply(modify_float,axis=0)
df_mad
# Out:
#      CaseID           Category  \
# 0         0   Challenging Math
# 1         1   Challenging Math
# 2         2   Challenging Math
# 3         3   Challenging Math
# 4         4   Challenging Math
# ..      ...                ...
# 272     220  disambiguation_qa
# 273     221  disambiguation_qa
# 274     222  disambiguation_qa
# 275     223  disambiguation_qa
# 276     224  disambiguation_qa
#
#                                               Question Correct Answer  \
# 0    Janet’s ducks lay 16 eggs per day. She eats th...       -9867630
# 1    James decides to run 1793815 sprints 1793815 t...      322886700
# 2    Every day, Wendi feeds each of her chickens th...       -6887448
# 3    Kylar went to the store to buy glasses for his...       21459061
# 4    Toulouse has twice as many sheep as Charleston...       82085198
# ..                                                 ...            ...
# 272  In the following sentences, explain the antece...              c
# 273  In the following sentences, explain the antece...              c
# 274  In the following sentences, explain the antece...              a
# 275  In the following sentences, explain the antece...              c
# 276  In the following sentences, explain the antece...              b
#
#                                               ori_cot1  \
# 0    Step 1: Calculate the total number of eggs Jan...
# 1    \r\n        Step 1: Calculate the total meters...
# 2                                                error
# 3    Step 1: Calculate the total number of glasses ...
# 4    \r\nStep 1: Let's denote the number of sheep i...
# ..                                                 ...
# 272  Step 1: Identify the pronoun in the sentence. ...
# 273  Step 1: Identify the pronoun in the sentence. ...
# 274  Step 1: The pronoun 'their' in the sentence re...
# 275  Step 1: Identify the pronoun in the sentence. ...
# 276                                              error
#
#                                               ori_cot2  ori_ans1   ori_ans2  \
# 0    \r\n        Step 1: Calculate the total number...  19735200    1973528
# 1    \r\n        Step 1: Calculate the total meters...        14  107628900
# 2    \r\n        Step 1: Calculate the total amount...     error         35
# 3    Step 1: Calculate the total number of glasses ...         2   16119180
# 4    \r\nStep 1: Let's denote the number of sheep i...  82085198   37885476
# ..                                                 ...       ...        ...
# 272  Step 1: Identify the pronoun in the sentence. ...         b          b
# 273  Step 1: Identify the pronoun in the sentence. ...         a          a
# 274  Step 1: Identify the pronoun in the sentence. ...         b          a
# 275  Step 1: Identify the pronoun in the sentence. ...         b          a
# 276  Step 1: The pronoun 'them' in the sentence 'Th...     error          b
#
#                                                   cot1  \
# 0    The solution provided by the other agents cont...
# 1    The solution provided by the other agents cont...
# 2    To determine how many cups of feed Wendi needs...
# 3    The initial solution provided by the other age...
# 4    The solution provided by the other agents is c...
# ..                                                 ...
# 272  Step 1: Identify the pronoun in the sentence. ...
# 273  The pronoun 'he' in the sentence 'Alex did not...
# 274  The pronoun 'their' in the sentence refers bac...
# 275  The full solution provided by the other agents...
# 276  In the sentence 'The designer collaborated wit...
#
#                                                   cot2  \
# 0    The solution provided by the other agents cont...
# 1    The solution provided by the other agents is m...
# 2    The solution provided by the other agents is m...
# 3    The solution provided by the other agents is m...
# 4    The solution provided by the other agents is c...
# ..                                                 ...
# 272  Step 1: Identify the pronoun in the sentence. ...
# 273  The full solution provided by the other agents...
# 274  The pronoun 'their' in the sentence 'The educa...
# 275  Step 1: Identify the pronoun in the sentence. ...
# 276  The pronoun 'them' in the sentence 'The design...
#
#                            ans1  \
# 0                            20
# 1        193276073935000 meters
# 2    Error in problem statement
# 3                    21,459,061
# 4                      82085198
# ..                          ...
# 272                           C
# 273                           C
# 274                           B
# 275                           A
# 276                           C
#
#                                                   ans2   MAD_answer
# 0                                                 $20            20
# 1                               193062269353500 meters  1.93276E+14
# 2    The problem statement contains a likely typo o...        error
# 3                                         $21,459,061      21459061
# 4                                             82085200     82085198
# ..                                                 ...          ...
# 272                                                  C            C
# 273                                                  C            C
# 274                                                  A            B
# 275                                                  A            A
# 276                                                  B            C
#
# [277 rows x 13 columns]

# %%
df_c3.iloc[1888:2165]
# Out:
#                Category                                           Question  \
# 1888   Challenging Math  Janet’s ducks lay 16 eggs per day. She eats th...
# 1889   Challenging Math  James decides to run 1793815 sprints 1793815 t...
# 1890   Challenging Math  Every day, Wendi feeds each of her chickens th...
# 1891   Challenging Math  Kylar went to the store to buy glasses for his...
# 1892   Challenging Math  Toulouse has twice as many sheep as Charleston...
# ...                 ...                                                ...
# 2160  disambiguation_qa  In the following sentences, explain the antece...
# 2161  disambiguation_qa  In the following sentences, explain the antece...
# 2162  disambiguation_qa  In the following sentences, explain the antece...
# 2163  disambiguation_qa  In the following sentences, explain the antece...
# 2164  disambiguation_qa  In the following sentences, explain the antece...
#
#       Consistency                                            raw_cot  \
# 1888        False  Step 1: Calculate the total number of eggs Jan...
# 1889        False  \r\n        Step 1: Calculate the total meters...
# 1890        False  \r\n        Step 1: Calculate the total amount...
# 1891        False  Step 1: Calculate the total number of glasses ...
# 1892        False  \r\nStep 1: Let's denote the number of sheep i...
# ...           ...                                                ...
# 2160        False  Step 1: Identify the pronoun in the sentence. ...
# 2161        False  Step 1: Identify the pronoun in the sentence. ...
# 2162        False  Step 1: Identify the pronoun in the sentence. ...
# 2163        False  Step 1: Identify the pronoun in the sentence. ...
# 2164        False  Step 1: Identify the pronoun in the sentence. ...
#
#                                           corrected_cot Correct_Answer  \
# 1888  Step 1: Calculate the total number of eggs Jan...       -9867630
# 1889  Step 1: Calculate the total meters James runs ...      322886700
# 1890  Step 1: Calculate the total amount of feed giv...       -6887448
# 1891  Step 1: Calculate the total number of glasses ...       21459061
# 1892  \r\nStep 1: Let's denote the number of sheep i...       82085198
# ...                                                 ...            ...
# 2160  Step 1: Identify the pronoun in the sentence. ...              C
# 2161  Step 1: Identify the pronoun in the sentence. ...              C
# 2162  Step 1: Identify the pronoun in the sentence. ...              A
# 2163  Step 1: Identify the pronoun in the sentence. ...              C
# 2164  Step 1: Identify the pronoun in the sentence. ...              B
#
#      Cot_random_answer Smv_Answer Output_Answer    Corrected COT Answer
# 1888           3431580    3431580       3431580                      18
# 1889          17414074   17414074      17414074  193276073935000 meters
# 1890                 1          1             1                      15
# 1891           8404732    8404732       8404732                16119180
# 1892                11         11            11                82176198
# ...                ...        ...           ...                     ...
# 2160                 A          A             A                       c
# 2161                 B          B             B                       b
# 2162                 A          A             A                       a
# 2163                 B          B             B                       a
# 2164                 B          B             B                       b
#
# [277 rows x 10 columns]

# %%
for row_indx in range(len(df_mad)):
    if df_c3.iloc[1888:2165].iloc[row_indx].Question == df_mad.iloc[row_indx].Question:
        pass
    else: print(row_indx)

# %%
mad_ans_li = df_c3.Cot_random_answer.tolist()
mad_ans_li[1888:2165] = df_mad.MAD_answer.tolist()

# %%
df_c3['MAD_Answer'] = mad_ans_li
df_c3['MAD_Answer'] = df_c3['MAD_Answer'].apply(modify_float)

# %%
compute_results(df_c3)
# Out:
# {'CoT': 0.675, 'SC': 0.692, 'MAD': 0.697, 'Rerailer': 0.73}

# %%
df_c3 = pd.read_csv('../../../result/claude_results.csv')
df_c3_big = pd.read_csv('final_result_claude3.csv')
df_c3['Hallu Seq'] = df_c3_big['Hallu Seq'].tolist()
df_c3
# Out:
#       Unnamed: 0                 Category  \
# 0              0  professional_accounting
# 1              1  professional_accounting
# 2              2  professional_accounting
# 3              3  professional_accounting
# 4              4  professional_accounting
# ...          ...                      ...
# 2474        2474        disambiguation_qa
# 2475        2475        disambiguation_qa
# 2476        2476        disambiguation_qa
# 2477        2477        disambiguation_qa
# 2478        2478        disambiguation_qa
#
#                                                Question  Consistency  \
# 0     Which of the following items is not subject to...        False
# 1     Pine Co. purchased land for $450000 as a facto...        False
# 2     Spark Co. buys cordless phones for $125 each a...        False
# 3     The standard deviations of Stocks A and B are ...        False
# 4     A shoe retailer allows customers to return sho...        False
# ...                                                 ...          ...
# 2474  In the following sentences, explain the antece...         True
# 2475  In the following sentences, explain the antece...         True
# 2476  In the following sentences, explain the antece...         True
# 2477  In the following sentences, explain the antece...         True
# 2478  In the following sentences, explain the antece...         True
#
#                                                 raw_cot  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 1: Calculate the profit per unit by subtr...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2474                                                NaN
# 2475                                                NaN
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
#
#                                           corrected_cot Correct_Answer  \
# 0     Step 1: To answer which item is not subject to...              D
# 1     Step 1: Understand that the cost to be capital...              C
# 2     Step 4: To summarize the thought process:\n\nS...              D
# 3     Step 1: Understand that the standard deviation...              A
# 4     Step 1: Understand the problem. The company ne...              B
# ...                                                 ...            ...
# 2474                                                NaN              B
# 2475                                                NaN              B
# 2476                                                NaN              C
# 2477                                                NaN              A
# 2478                                                NaN              B
#
#                                       Cot_random_answer  \
# 0                                                     B
# 1                                                     D
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2474                                                  B
# 2475                                                  B
# 2476                                                  C
# 2477                                                  C
# 2478                                                  C
#
#                                              Smv_Answer  \
# 0                                                     B
# 1                                                     D
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2474                                                  B
# 2475                                                  B
# 2476                                                  C
# 2477                                                  C
# 2478                                                  C
#
#                                           Output_Answer  \
# 0                                                     B
# 1                                                     A
# 2                                                     D
# 3     None of the options match the calculated value...
# 4                                                     B
# ...                                                 ...
# 2474                                                  B
# 2475                                                  B
# 2476                                                  C
# 2477                                                  C
# 2478                                                  C
#
#                                    Corrected COT Answer  \
# 0                                                     d
# 1                                                     a
# 2                                                     d
# 3     none of the given options (a) 10%, (b) 5%, (c)...
# 4                                                     b
# ...                                                 ...
# 2474                                                  B
# 2475                                                  B
# 2476                                                  C
# 2477                                                  C
# 2478                                                  C
#
#                                              MAD_Answer  \
# 0                                                     B
# 1                                                     D
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2474                                                  B
# 2475                                                  B
# 2476                                                  C
# 2477                                                  C
# 2478                                                  C
#
#                                              Hallu Seq
# 0                 ['NO', 'NO', 'NO', 'NO', 'NO', 'NO']
# 1           ['NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO']
# 2     ['NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO']
# 3           ['NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO']
# 4                       ['NO', 'NO', 'NO', 'NO', 'NO']
# ...                                                ...
# 2474                                               NaN
# 2475                                               NaN
# 2476                                               NaN
# 2477                                               NaN
# 2478                                               NaN
#
# [2479 rows x 13 columns]

# %%
df_c3.to_csv('../../../result/claude_results.csv',index=False)

# %%
df_c3
# Out:
#                      Category  \
# 0     professional_accounting
# 1     professional_accounting
# 2     professional_accounting
# 3     professional_accounting
# 4     professional_accounting
# ...                       ...
# 2469        disambiguation_qa
# 2470        disambiguation_qa
# 2471        disambiguation_qa
# 2472        disambiguation_qa
# 2473        disambiguation_qa
#
#                                                Question  Consistency  \
# 0     Which of the following items is not subject to...        False
# 1     Pine Co. purchased land for $450000 as a facto...        False
# 2     Spark Co. buys cordless phones for $125 each a...        False
# 3     The standard deviations of Stocks A and B are ...        False
# 4     A shoe retailer allows customers to return sho...        False
# ...                                                 ...          ...
# 2469  In the following sentences, explain the antece...         True
# 2470  In the following sentences, explain the antece...         True
# 2471  In the following sentences, explain the antece...         True
# 2472  In the following sentences, explain the antece...         True
# 2473  In the following sentences, explain the antece...         True
#
#                                                 raw_cot  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 1: Calculate the profit per unit by subtr...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2469                                                NaN
# 2470                                                NaN
# 2471                                                NaN
# 2472                                                NaN
# 2473                                                NaN
#
#                                           corrected_cot Correct_Answer  \
# 0     Step 1: Understand what intraperiod tax alloca...              D
# 1     Step 1: Understand that the cost to be capital...              C
# 2     Step 1: Calculate the profit per unit by subtr...              D
# 3     Step 1: Understand that the standard deviation...              A
# 4     Step 1: Understand the problem. The company ne...              B
# ...                                                 ...            ...
# 2469                                                NaN              C
# 2470                                                NaN              B
# 2471                                                NaN              B
# 2472                                                NaN              C
# 2473                                                NaN              A
#
#                                       Cot_random_answer  \
# 0                                                     B
# 1                                                     D
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2469                                                  A
# 2470                                                  B
# 2471                                                  B
# 2472                                                  C
# 2473                                                  A
#
#                                              Smv_Answer  \
# 0                                                     B
# 1                                                     D
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2469                                                  A
# 2470                                                  B
# 2471                                                  B
# 2472                                                  C
# 2473                                                  A
#
#                                           Output_Answer Corrected COT Answer  \
# 0                                                     B                    b
# 1                                                     A                    a
# 2                                                     D                    d
# 3     None of the options match the calculated value...                    a
# 4                                                     B                    b
# ...                                                 ...                  ...
# 2469                                                  A                    A
# 2470                                                  B                    B
# 2471                                                  B                    B
# 2472                                                  C                    C
# 2473                                                  A                    A
#
#                                              MAD_Answer
# 0                                                     B
# 1                                                     D
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2469                                                  A
# 2470                                                  B
# 2471                                                  B
# 2472                                                  C
# 2473                                                  A
#
# [2474 rows x 11 columns]

# %%
df_test = pd.read_csv('final_result_claude3.csv')
df_test
# Out:
#                      Category  \
# 0     professional_accounting
# 1     professional_accounting
# 2     professional_accounting
# 3     professional_accounting
# 4     professional_accounting
# ...                       ...
# 2474        disambiguation_qa
# 2475        disambiguation_qa
# 2476        disambiguation_qa
# 2477        disambiguation_qa
# 2478        disambiguation_qa
#
#                                                Question Correct_Answer  \
# 0     Which of the following items is not subject to...              D
# 1     Pine Co. purchased land for $450000 as a facto...              C
# 2     Spark Co. buys cordless phones for $125 each a...              D
# 3     The standard deviations of Stocks A and B are ...              A
# 4     A shoe retailer allows customers to return sho...              B
# ...                                                 ...            ...
# 2474  In the following sentences, explain the antece...              B
# 2475  In the following sentences, explain the antece...              B
# 2476  In the following sentences, explain the antece...              C
# 2477  In the following sentences, explain the antece...              A
# 2478  In the following sentences, explain the antece...              B
#
#                                           Output_Answer  Consistency  \
# 0                                                     B        False
# 1                                                     A        False
# 2                                                     D        False
# 3     None of the options match the calculated value...        False
# 4                                                     B        False
# ...                                                 ...          ...
# 2474                                                  B         True
# 2475                                                  B         True
# 2476                                                  C         True
# 2477                                                  C         True
# 2478                                                  C         True
#
#                                                     Cot  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 1: Calculate the profit per unit by subtr...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2474                                                NaN
# 2475                                                NaN
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
#
#                                              Cot_Answer  \
# 0                                                     D
# 1                                                     A
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2474                                                NaN
# 2475                                                NaN
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
#
#                                              Smv_Answer  \
# 0                                                     B
# 1                                                     D
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2474                                                  B
# 2475                                                  B
# 2476                                                  C
# 2477                                                  C
# 2478                                                  C
#
#                                              Cot_random  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     step 1: Understand that the cost of the comple...
# 2     step 1: Calculate the desired profit margin, w...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2474                                                NaN
# 2475                                                NaN
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
#
#                                       Cot_random_answer  ...  \
# 0                                                     B  ...
# 1                                                     D  ...
# 2     The calculation process was flawed, leading to...  ...
# 3     None of the options match the calculated value...  ...
# 4                                                     C  ...
# ...                                                 ...  ...
# 2474                                                  B  ...
# 2475                                                  B  ...
# 2476                                                  C  ...
# 2477                                                  C  ...
# 2478                                                  C  ...
#
#                                                 raw_cot  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 1: Calculate the profit per unit by subtr...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2474                                                NaN
# 2475                                                NaN
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
#
#                                           corrected_cot  \
# 0     Step 1: To answer which item is not subject to...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 4: To summarize the thought process:\n\nS...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2474                                                NaN
# 2475                                                NaN
# 2476                                                NaN
# 2477                                                NaN
# 2478                                                NaN
#
#                         Model           Name  \
# 0                         NaN            NaN
# 1                         NaN            NaN
# 2                         NaN            NaN
# 3                         NaN            NaN
# 4                         NaN            NaN
# ...                       ...            ...
# 2474  claude-3-haiku-20240307  BigBench_hard
# 2475  claude-3-haiku-20240307  BigBench_hard
# 2476  claude-3-haiku-20240307  BigBench_hard
# 2477  claude-3-haiku-20240307  BigBench_hard
# 2478  claude-3-haiku-20240307  BigBench_hard
#
#                                                    cot1  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2474  Step 1: In the given sentence, the pronoun 'hi...
# 2475  Step 1: Identify the pronouns in the sentence....
# 2476  Step 1: Identify the pronoun in the sentence. ...
# 2477  Step 1: The sentence is 'The educator was meet...
# 2478  Step 1: In the given sentence, the pronoun 'th...
#
#                                                    cot2  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2474  Step 1: The sentence is 'After meeting with th...
# 2475  Step 1: Identify the pronouns in the given sen...
# 2476  Step 1: Identify the pronoun in the sentence. ...
# 2477  Step 1: The sentence states 'their grading pol...
# 2478  Step 1: The sentence is 'The designer collabor...
#
#                                                    cot3 answer1 answer2  \
# 0                                                   NaN     NaN     NaN
# 1                                                   NaN     NaN     NaN
# 2                                                   NaN     NaN     NaN
# 3                                                   NaN     NaN     NaN
# 4                                                   NaN     NaN     NaN
# ...                                                 ...     ...     ...
# 2474  Step 1: Identify the pronoun in the sentence. ...       B       B
# 2475  Step 1: The pronoun 'him' in the given sentenc...       B       B
# 2476  Step 1: The given sentence is 'The developer m...       C       C
# 2477  Step 1: The sentence mentions 'the educator' a...       C       C
# 2478  Step 1: The pronoun 'them' in the sentence 'Th...       C       C
#
#      answer3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 2474       B
# 2475       B
# 2476       C
# 2477       C
# 2478       C
#
# [2479 rows x 25 columns]

# %%
df_test.fillna('error',inplace=True)
df_test['Model'] = 'claude-3-sonnet'
df_test.drop(columns='Name',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 3
#       1 df_test.fillna('error',inplace=True)
#       2 df_test['Model'] = 'claude-3-sonnet'
# ----> 3 df_test.drop(columns='Name',inplace=True)
#       4 for row_index in range(len(df_test)):
#       5     row = df_test.iloc[row_indx]
#
# File W:\anaconda3\envs\llm_hall_project\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File W:\anaconda3\envs\llm_hall_project\lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File W:\anaconda3\envs\llm_hall_project\lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File W:\anaconda3\envs\llm_hall_project\lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['Name'] not found in axis"

# %%
for row_index in range(len(df_test)):
    row = df_test.iloc[row_indx]
    if row['cot1'] == 'error':
        row['cot1'] = row['raw_cot']
    df_test.iloc[row_indx] = row
df_test
# Out:
# C:\Users\77388\AppData\Local\Temp\ipykernel_11540\1186901136.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row['cot1'] = row['raw_cot']
#                      Category  \
# 0     professional_accounting
# 1     professional_accounting
# 2     professional_accounting
# 3     professional_accounting
# 4     professional_accounting
# ...                       ...
# 2474        disambiguation_qa
# 2475        disambiguation_qa
# 2476        disambiguation_qa
# 2477        disambiguation_qa
# 2478        disambiguation_qa
#
#                                                Question Correct_Answer  \
# 0     Which of the following items is not subject to...              D
# 1     Pine Co. purchased land for $450000 as a facto...              C
# 2     Spark Co. buys cordless phones for $125 each a...              D
# 3     The standard deviations of Stocks A and B are ...              A
# 4     A shoe retailer allows customers to return sho...              B
# ...                                                 ...            ...
# 2474  In the following sentences, explain the antece...              B
# 2475  In the following sentences, explain the antece...              B
# 2476  In the following sentences, explain the antece...              C
# 2477  In the following sentences, explain the antece...              A
# 2478  In the following sentences, explain the antece...              B
#
#                                           Output_Answer  Consistency  \
# 0                                                     B        False
# 1                                                     A        False
# 2                                                     D        False
# 3     None of the options match the calculated value...        False
# 4                                                     B        False
# ...                                                 ...          ...
# 2474                                                  B         True
# 2475                                                  B         True
# 2476                                                  C         True
# 2477                                                  C         True
# 2478                                                  C         True
#
#                                                     Cot  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 1: Calculate the profit per unit by subtr...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2474                                              error
# 2475                                              error
# 2476                                              error
# 2477                                              error
# 2478                                              error
#
#                                              Cot_Answer  \
# 0                                                     D
# 1                                                     A
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2474                                              error
# 2475                                              error
# 2476                                              error
# 2477                                              error
# 2478                                              error
#
#                                              Smv_Answer  \
# 0                                                     B
# 1                                                     D
# 2     The calculation process was flawed, leading to...
# 3     None of the options match the calculated value...
# 4                                                     C
# ...                                                 ...
# 2474                                                  B
# 2475                                                  B
# 2476                                                  C
# 2477                                                  C
# 2478                                                  C
#
#                                              Cot_random  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     step 1: Understand that the cost of the comple...
# 2     step 1: Calculate the desired profit margin, w...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2474                                              error
# 2475                                              error
# 2476                                              error
# 2477                                              error
# 2478                                              error
#
#                                       Cot_random_answer  ...  \
# 0                                                     B  ...
# 1                                                     D  ...
# 2     The calculation process was flawed, leading to...  ...
# 3     None of the options match the calculated value...  ...
# 4                                                     C  ...
# ...                                                 ...  ...
# 2474                                                  B  ...
# 2475                                                  B  ...
# 2476                                                  C  ...
# 2477                                                  C  ...
# 2478                                                  C  ...
#
#                                              Hallu Seq  \
# 0                 ['NO', 'NO', 'NO', 'NO', 'NO', 'NO']
# 1           ['NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO']
# 2     ['NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO']
# 3           ['NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO']
# 4                       ['NO', 'NO', 'NO', 'NO', 'NO']
# ...                                                ...
# 2474                                             error
# 2475                                             error
# 2476                                             error
# 2477                                             error
# 2478                                             error
#
#                                                 raw_cot  \
# 0     Step 1: Understand what intraperiod tax alloca...
# 1     Step 1: Understand that the cost to be capital...
# 2     Step 1: Calculate the profit per unit by subtr...
# 3     Step 1: Understand that the standard deviation...
# 4     Step 1: Understand the problem. The company ne...
# ...                                                 ...
# 2474                                              error
# 2475                                              error
# 2476                                              error
# 2477                                              error
# 2478                                              error
#
#                                           corrected_cot            Model  \
# 0     Step 1: To answer which item is not subject to...  claude-3-sonnet
# 1     Step 1: Understand that the cost to be capital...  claude-3-sonnet
# 2     Step 4: To summarize the thought process:\n\nS...  claude-3-sonnet
# 3     Step 1: Understand that the standard deviation...  claude-3-sonnet
# 4     Step 1: Understand the problem. The company ne...  claude-3-sonnet
# ...                                                 ...              ...
# 2474                                              error  claude-3-sonnet
# 2475                                              error  claude-3-sonnet
# 2476                                              error  claude-3-sonnet
# 2477                                              error  claude-3-sonnet
# 2478                                              error  claude-3-sonnet
#
#                                                    cot1  \
# 0                                                 error
# 1                                                 error
# 2                                                 error
# 3                                                 error
# 4                                                 error
# ...                                                 ...
# 2474  Step 1: In the given sentence, the pronoun 'hi...
# 2475  Step 1: Identify the pronouns in the sentence....
# 2476  Step 1: Identify the pronoun in the sentence. ...
# 2477  Step 1: The sentence is 'The educator was meet...
# 2478  Step 1: In the given sentence, the pronoun 'th...
#
#                                                    cot2  \
# 0                                                 error
# 1                                                 error
# 2                                                 error
# 3                                                 error
# 4                                                 error
# ...                                                 ...
# 2474  Step 1: The sentence is 'After meeting with th...
# 2475  Step 1: Identify the pronouns in the given sen...
# 2476  Step 1: Identify the pronoun in the sentence. ...
# 2477  Step 1: The sentence states 'their grading pol...
# 2478  Step 1: The sentence is 'The designer collabor...
#
#                                                    cot3 answer1 answer2  \
# 0                                                 error   error   error
# 1                                                 error   error   error
# 2                                                 error   error   error
# 3                                                 error   error   error
# 4                                                 error   error   error
# ...                                                 ...     ...     ...
# 2474  Step 1: Identify the pronoun in the sentence. ...       B       B
# 2475  Step 1: The pronoun 'him' in the given sentenc...       B       B
# 2476  Step 1: The given sentence is 'The developer m...       C       C
# 2477  Step 1: The sentence mentions 'the educator' a...       C       C
# 2478  Step 1: The pronoun 'them' in the sentence 'Th...       C       C
#
#      answer3
# 0      error
# 1      error
# 2      error
# 3      error
# 4      error
# ...      ...
# 2474       B
# 2475       B
# 2476       C
# 2477       C
# 2478       C
#
# [2479 rows x 24 columns]
